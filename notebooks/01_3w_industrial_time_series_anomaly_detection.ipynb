# %% [markdown]
# # Industrial Time-Series Anomaly Detection for Oil Wells
#
# This notebook provides a polished walkthrough of the project from problem statement to modeling and evaluation.

# %% [markdown]
# ## 1. Problem statement
#
# Oil well operations generate large amounts of time-series sensor data. The goal is to detect abnormal conditions early so that operators can act before failures become serious.

# %% [markdown]
# ## 2. Data and approach
#
# The workflow uses sensor measurements, class labels, and time-based structure to build a supervised anomaly detector.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))
from src.pipeline import run_pipeline

print('Pipeline module imported successfully.')

# %% [markdown]
# ## 3. Feature engineering
#
# Lag features and rolling-window statistics are used to capture both short-term and longer-term temporal behavior.

# %% [markdown]
# ## 4. Model training and evaluation
#
# A Random Forest classifier is trained to distinguish abnormal from normal states, and threshold tuning is explored for alert generation.

# %% [markdown]
# ## 5. Results and interpretation
#
# The resulting outputs can be saved as CSV files and model artifacts for reporting and further analysis.

# %%
# Example usage:
# result = run_pipeline('path/to/dataset_root', 'outputs')
# result['metrics']
